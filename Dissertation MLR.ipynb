# %%
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv('Data.csv')
print ("\nPrinting the data...\n")
print (df.head())
# Out:
# Printing the data...
#
#         month  yield_spread  unemployment_rate  recession
# 0  01/01/1982          1.76                8.6          1
# 1  01/02/1982          0.10                8.9          1
# 2  01/03/1982          0.55                9.0          1
# 3  01/04/1982          0.51                9.3          1
# 4  01/05/1982          0.95                9.4          1

# %%
X = df[['yield_spread','recession']]
Y = df['unemployment_rate']
X = sm.add_constant(X) 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)

# %%
spread = df['yield_spread']
unemployment = df['unemployment_rate']
import seaborn as sns; sns.set(color_codes=True)
ax = sns.regplot(x=spread, y=unemployment, data=df)

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           yield_spread   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     122.4
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):           4.69e-43
# Time:                        20:37:25   Log-Likelihood:                -572.85
# No. Observations:                 446   AIC:                             1152.
# Df Residuals:                     443   BIC:                             1164.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.5910      0.159     -3.708      0.000      -0.904      -0.278
# ...

# %%
X = df[['unemployment_rate','recession']]
Y = df['yield_spread']
X = sm.add_constant(X) 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X)

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           yield_spread   R-squared:                       0.356
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     122.4
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):           4.69e-43
# Time:                        19:55:07   Log-Likelihood:                -572.85
# No. Observations:                 446   AIC:                             1152.
# Df Residuals:                     443   BIC:                             1164.
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.5910      0.159     -3.708      0.000      -0.904      -0.278
# ...

# %%
X3 = df[['unemployment_rate']]
Y3 = df['yield_spread']
X3 = sm.add_constant(X3)
model3 = sm.OLS(Y3, X3).fit()
predictions = model3.predict(X3)

# %%
print(model3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           yield_spread   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.353
# Method:                 Least Squares   F-statistic:                     243.9
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):           3.87e-44
# Time:                        19:55:07   Log-Likelihood:                -573.33
# No. Observations:                 446   AIC:                             1151.
# Df Residuals:                     444   BIC:                             1159.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                -0.5793      0.159     -3.645      0.000      -0.892      -0.267
# ...
